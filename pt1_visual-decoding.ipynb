# %% [markdown]
# # Intro to data visualization
# Schedule
# - 00:00 - Overview & start notebook
# - 00:10 - Visual Decoding
# - 00:20 - Visual Encoding basics
# - 00:30 - Visual Encoding BrAiNs

# %% [markdown]
# ![image.png](attachment:816c4247-b0d6-4f87-a78b-ef72da20dd86.png)

# %% [markdown]
# # Visual decoding
# aka, seeing an figure and understanding what it means

# %% [markdown]
# # Space

# %% [markdown]
# ### Which is 2x black, green or pink?
# ![image.png](attachment:4024c6c2-c96a-4830-b65a-f6c85f530a0c.png)

# %% [markdown]
# ![image.png](attachment:3a10a305-dc08-458e-8ab2-bb0927fc9850.png)

# %% [markdown]
# ## Perceptual errors when visualizing amounts
# ![image.png](attachment:94153edd-1bc3-4f48-a374-688c0a38ba5b.png)

# %% [markdown]
# # Color and lightness
# ## Which is 2x lighter than the leftmost box?
#
# ![image.png](attachment:b035adca-548c-4d63-95c5-ca9d49d18447.png)

# %% [markdown]
# ## Which color is lightest?
# ![image.png](attachment:05c97489-12f6-483b-8058-6e16b8a1babe.png)

# %% [markdown]
# ![image.png](attachment:565961ac-8d0e-49b2-8b67-bc36a9419279.png)

# %% [markdown]
# ![image.png](attachment:04f2b446-b32b-4395-8f01-65a68e551055.png)

# %% [markdown]
# ![image.png](attachment:5aaee4ba-ead4-4fe7-933f-1c4edcd1a3b0.png)

# %% [markdown]
# ## Physical vs perceived intensity
# ![image.png](attachment:bb5b1894-f875-403a-8f11-6f17088704f5.png)

# %% [markdown]
# ## Types of colormaps
#
# ![image.png](attachment:dc8ed31d-4211-4fa5-9f21-2ee984af5333.png)

# %% [markdown]
# # Redundant encoding
# aka communicating information with in more than one way
# ![image.png](attachment:e77f5c75-8aa8-435c-996d-288666e87882.png)

# %% [markdown]
# # Reference sheets

# %% [markdown]
# ## Channel effectiveness
# ![image.png](attachment:38178181-0253-46e5-92ed-7f466753bc9f.png)

# %% [markdown]
# ## Choosing plot types
# ![image.png](attachment:95709ac3-1079-40b3-bec0-c0711251fa46.png)

# %% [markdown]
# ## Choosing colors
# ![image.png](attachment:8ac1111f-367c-4741-903d-ec3c86604c93.png)

# %% [markdown]
# # Next up... Visual Encoding
# aka implementing these principles in Python
